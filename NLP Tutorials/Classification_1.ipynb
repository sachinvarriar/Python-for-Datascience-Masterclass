# %%
def gender_features(word):
    return {'last_letter': word[-1]}

# %%
gender_features('shrek')
# Out:
# {'last_letter': 'k'}

# %%
from nltk.corpus import names
import random
import nltk
nltk.download('names')
# Out:
# [nltk_data] Downloading package names to
# [nltk_data]     C:\Users\sachi\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\names.zip.
# True

# %%
names = ([(name, 'male') for name in names.words('male.txt')] +
... [(name, 'female') for name in names.words('female.txt')])

# %%
random.shuffle(names)

# %%
print(names)
# Out:
# [('Jerrie', 'female'), ('Eugene', 'male'), ('Ruperta', 'female'), ('Clem', 'female'), ('Renata', 'female'), ('Cristin', 'female'), ('Lesley', 'female'), ('Kirk', 'male'), ('Lacey', 'female'), ('Erna', 'female'), ('Kynthia', 'female'), ('Danie', 'male'), ('Jo', 'female'), ('Silvia', 'female'), ('Noam', 'male'), ('Ruben', 'male'), ('Lorrie', 'male'), ('Milissent', 'female'), ('Lucas', 'male'), ('Euclid', 'male'), ('Tan', 'male'), ('Dirk', 'male'), ('Towney', 'male'), ('Hanan', 'male'), ('Sibylla', 'female'), ('Onlea', 'female'), ('Farah', 'female'), ('Filippa', 'female'), ('Glynis', 'female'), ('Darleen', 'female'), ('Jasmina', 'female'), ('Philomena', 'female'), ('Orelie', 'female'), ('Toby', 'female'), ('Katerine', 'female'), ('Zerk', 'male'), ('Temp', 'male'), ('Sarajane', 'female'), ('Kelley', 'male'), ('Millisent', 'female'), ('Adria', 'female'), ('Ruth', 'female'), ('Koral', 'female'), ('Beverly', 'female'), ('Maurits', 'male'), ('Damaris', 'female'), ('Bernice', 'female'), ('Lainey', 'female'), ('Stearne', 'male'), ('Othelia', 'female'), ('Lind', 'female'), ('Darrell', 'male'), ('Wang', 'male'), ('Francisca', 'female'), ('Mattie', 'male'), ('Laraine', 'female'), ('Margalo', 'female'), ('Merrick', 'male'), ('Renato', 'male'), ('Francene', 'female'), ('Parsifal', 'male'), ('Bonnie', 'female'), ('Rinaldo', 'male'), ('Devon', 'female'), ('Phillis', 'female'), ('Milicent', 'female'), ('Kattie', 'female'), ('Myke', 'male'), ('Janine', 'female'), ('Dorothy', 'female'), ('Patience', 'female'), ('Cariotta', 'female'), ('Vinny', 'male'), ('Osbert', 'male'), ('Mariya', 'female'), ('Lazlo', 'male'), ('Kathryn', 'female'), ('Christen', 'female'), ('Donn', 'male'), ('Marci', 'female'), ('Thatch', 'male'), ('Doyle', 'male'), ('Michaela', 'female'), ('Diamond', 'female'), ('Hamlin', 'male'), ('Arvy', 'male'), ('Spud', 'male'), ('Cresa', 'female'), ('Arlyn', 'female'), ('Elfrieda', 'female'), ('Martha', 'female'), ('Amity', 'female'), ('Sheila-Kathryn', 'female'), ('Joby', 'female'), ('Lisetta', 'female'), ('Jamey', 'male'), ('Caroleen', 'female'), ('Jolee', 'female'), ('Holley', 'female'), ('Karlene', 'female'), ('Shandie', 'female'), ('Rem', 'male'), ('Nicolina', 'female'), ('Carrissa', 'female'), ('Elyn', 'female'), ('Ginger', 'male'), ('Ray', 'male'), ('Paddy', 'male'), ('Steffane', 'female'), ('Benny', 'male'), ('Steward', 'male'), ('Bette-Ann', 'female'), ('Dion', 'female'), ('Caitlin', 'female'), ('Malina', 'female'), ('Queada', 'female'), ('Lyndsie', 'female'), ('Gussi', 'female'), ('Vera', 'female'), ('Gerhardt', 'male'), ('Celeste', 'female'), ('Angelia', 'female'), ('Kate', 'female'), ('Raynell', 'female'), ('Melodie', 'female'), ('Joline', 'female'), ('Luanna', 'female'), ('Nichole', 'male'), ('Mab', 'female'), ('Merwin', 'male'), ('Staffard', 'male'), ('Ramonda', 'female'), ('Gwenette', 'female'), ('Ryan', 'male'), ('Willdon', 'male'), ('Debbi', 'female'), ('Riki', 'female'), ('Rheta', 'female'), ('Dion', 'male'), ('Rora', 'female'), ('Mellisent', 'female'), ('Taite', 'male'), ('Damita', 'female'), ('Pandora', 'female'), ('Collete', 'female'), ('Clare', 'male'), ('Toby', 'male'), ('Janella', 'female'), ('Cat', 'female'), ('Gillan', 'female'), ('Paige', 'male'), ('Fayre', 'female'), ('Sandra', 'female'), ('Maisie', 'female'), ('Nidia', 'female'), ('Kaylil', 'female'), ('Robinette', 'female'), ('Madonna', 'female'), ('Hillery', 'male'), ('Lynn', 'male'), ('Klarika', 'female'), ('Gretna', 'female'), ('Mortie', 'male'), ('Zonnya', 'female'), ('Ranna', 'female'), ('Rachele', 'female'), ('Karlyn', 'female'), ('Antone', 'male'), ('Teodorico', 'male'), ('Apostolos', 'male'), ('Marni', 'female'), ('Nellie', 'female'), ('Lay', 'male'), ('Barth', 'male'), ('Robinet', 'female'), ('Aileen', 'female'), ('Leola', 'female'), ('Row', 'female'), ('Idalina', 'female'), ('Lem', 'male'), ('Emlyn', 'female'), ('Johny', 'male'), ('Easton', 'male'), ('Gerold', 'male'), ('Engracia', 'female'), ('Willy', 'female'), ('Hephzibah', 'female'), ('Sonni', ' ...

# %%
len(names)
# Out:
# 7944

# %%
featuresets = [(gender_features(n), g) for (n,g) in names]

# %%
train_set, test_set = featuresets[500:], featuresets[:500]

# %%
len(train_set)
# Out:
# 7444

# %%
len(test_set)
# Out:
# 500

# %%
classifier = nltk.NaiveBayesClassifier.train(train_set)

# %%
print(nltk.classify.accuracy(classifier, test_set))
# Out:
# 0.72

# %%
classifier.show_most_informative_features(30)
# Out:
# Most Informative Features
#              last_letter = 'a'            female : male   =     33.1 : 1.0
#              last_letter = 'k'              male : female =     31.5 : 1.0
#              last_letter = 'p'              male : female =     19.9 : 1.0
#              last_letter = 'f'              male : female =     16.8 : 1.0
#              last_letter = 'v'              male : female =     10.6 : 1.0
#              last_letter = 'd'              male : female =     10.1 : 1.0
#              last_letter = 'm'              male : female =      9.1 : 1.0
#              last_letter = 'o'              male : female =      9.0 : 1.0
#              last_letter = 'r'              male : female =      6.7 : 1.0
#              last_letter = 'w'              male : female =      6.6 : 1.0
#              last_letter = 'g'              male : female =      5.1 : 1.0
#              last_letter = 'z'              male : female =      5.1 : 1.0
#              last_letter = 's'              male : female =      4.6 : 1.0
#              last_letter = 't'              male : female =      4.3 : 1.0
#              last_letter = 'b'              male : female =      4.1 : 1.0
#              last_letter = 'j'              male : female =      4.0 : 1.0
#              last_letter = 'i'            female : male   =      3.5 : 1.0
#              last_letter = 'u'              male : female =      3.3 : 1.0
#              last_letter = 'n'              male : female =      2.1 : 1.0
#              last_letter = 'e'            female : male   =      1.8 : 1.0
#              last_letter = 'l'              male : female =      1.7 : 1.0
#              last_letter = 'x'              male : female =      1.5 : 1.0
#              last_letter = 'h'              male : female =      1.5 : 1.0
#              last_letter = 'y'              male : female =      1.2 : 1.0

# %%
from nltk.classify import apply_features

# %%
train_set = apply_features(gender_features, names[500:])
test_set = apply_features(gender_features, names[:500])

# %%
print(train_set)
# Out:
# [({'last_letter': 'n'}, 'female'), ({'last_letter': 'e'}, 'female'), ...]

# %%
def gender_features(word):
    return {'last_letter': word[-1],
           'penultimate':word[-2]}

# %%
featuresets = [(gender_features(n), g) for (n,g) in names]

# %%
print(featuresets)
# Out:
# [({'last_letter': 'e', 'penultimate': 'i'}, 'female'), ({'last_letter': 'e', 'penultimate': 'n'}, 'male'), ({'last_letter': 'a', 'penultimate': 't'}, 'female'), ({'last_letter': 'm', 'penultimate': 'e'}, 'female'), ({'last_letter': 'a', 'penultimate': 't'}, 'female'), ({'last_letter': 'n', 'penultimate': 'i'}, 'female'), ({'last_letter': 'y', 'penultimate': 'e'}, 'female'), ({'last_letter': 'k', 'penultimate': 'r'}, 'male'), ({'last_letter': 'y', 'penultimate': 'e'}, 'female'), ({'last_letter': 'a', 'penultimate': 'n'}, 'female'), ({'last_letter': 'a', 'penultimate': 'i'}, 'female'), ({'last_letter': 'e', 'penultimate': 'i'}, 'male'), ({'last_letter': 'o', 'penultimate': 'J'}, 'female'), ({'last_letter': 'a', 'penultimate': 'i'}, 'female'), ({'last_letter': 'm', 'penultimate': 'a'}, 'male'), ({'last_letter': 'n', 'penultimate': 'e'}, 'male'), ({'last_letter': 'e', 'penultimate': 'i'}, 'male'), ({'last_letter': 't', 'penultimate': 'n'}, 'female'), ({'last_letter': 's', 'penultimate': 'a'}, 'male'), ({'last_letter': 'd', 'penultimate': 'i'}, 'male'), ({'last_letter': 'n', 'penultimate': 'a'}, 'male'), ({'last_letter': 'k', 'penultimate': 'r'}, 'male'), ({'last_letter': 'y', 'penultimate': 'e'}, 'male'), ({'last_letter': 'n', 'penultimate': 'a'}, 'male'), ({'last_letter': 'a', 'penultimate': 'l'}, 'female'), ({'last_letter': 'a', 'penultimate': 'e'}, 'female'), ({'last_letter': 'h', 'penultimate': 'a'}, 'female'), ({'last_letter': 'a', 'penultimate': 'p'}, 'female'), ({'last_letter': 's', 'penultimate': 'i'}, 'female'), ({'last_letter': 'n', 'penultimate': 'e'}, 'female'), ({'last_letter': 'a', 'penultimate': 'n'}, 'female'), ({'last_letter': 'a', 'penultimate': 'n'}, 'female'), ({'last_letter': 'e', 'penultimate': 'i'}, 'female'), ({'last_letter': 'y', 'penultimate': 'b'}, 'female'), ({'last_letter': 'e', 'penultimate': 'n'}, 'female'), ({'last_letter': 'k', 'penultimate': 'r'}, 'male'), ({'last_letter': 'p', 'penultimate': 'm'}, 'male'), ({'last_letter': 'e', 'penultimate': 'n'}, 'female'), ({'last_letter': 'y', 'penultimate': 'e'}, 'male'), ({'last_letter': 't', 'penultimate': 'n'}, 'female'), ({'last_letter': 'a', 'penultimate': 'i'}, 'female'), ({'last_letter': 'h', 'penultimate': 't'}, 'female'), ({'last_letter': 'l', 'penultimate': 'a'}, 'female'), ({'last_letter': 'y', 'penultimate': 'l'}, 'female'), ({'last_letter': 's', 'penultimate': 't'}, 'male'), ({'last_letter': 's', 'penultimate': 'i'}, 'female'), ({'last_letter': 'e', 'penultimate': 'c'}, 'female'), ({'last_letter': 'y', 'penultimate': 'e'}, 'female'), ({'last_letter': 'e', 'penultimate': 'n'}, 'male'), ({'last_letter': 'a', 'penultimate': 'i'}, 'female'), ({'last_letter': 'd', 'penultimate': 'n'}, 'female'), ({'last_letter': 'l', 'penultimate': 'l'}, 'male'), ({'last_letter': 'g', 'penultimate': 'n'}, 'male'), ({'last_letter': 'a', 'penultimate': 'c'}, 'female'), ({'last_letter': 'e', 'penultimate': 'i'}, 'male'), ({'last_letter': 'e', 'penultimate': 'n'}, 'female'), ({'last_letter': 'o', 'penultimate': 'l'}, 'female'), ({'last_letter': 'k', 'penultimate': 'c'}, 'male'), ({'last_letter': 'o', 'penultimate': 't'}, 'male'), ({'last_letter': 'e', 'penultimate': 'n'}, 'female'), ({'last_letter': 'l', 'penultimate': 'a'}, 'male'), ({'last_letter': 'e', 'penultimate': 'i'}, 'female'), ({'last_letter': 'o', 'penultimate': 'd'}, 'male'), ({'last_letter': 'n', 'penultimate': 'o'}, 'female'), ({'last_letter': 's', 'penultimate': 'i'}, 'female'), ({'last_letter': 't', 'penultimate': 'n'}, 'female'), ({'last_letter': 'e', 'penultimate': 'i'}, 'female'), ({'last_letter': 'e', 'penultimate': 'k'}, 'male'), ({'last_letter': 'e', 'penultimate': 'n'}, 'female'), ({'last_letter': 'y', 'penultimate': 'h'}, 'female'), ({'last_letter': 'e', 'penultimate': 'c'}, 'female'), ({'last_letter': 'a', 'penultimate': 't'}, 'female'), ({'last_letter': 'y', 'penultimate': 'n'}, 'male'), ({'last_letter': 't', 'penultimate': 'r'}, 'male'), ({'last_letter': 'a', 'penultimate': 'y'}, 'female'), ({' ...

# %%
train_set, test_set = featuresets[500:], featuresets[:500]

# %%
classifier = nltk.NaiveBayesClassifier.train(train_set)

# %%
print(nltk.classify.accuracy(classifier, test_set))
# Out:
# 0.722

# %%
classifier.show_most_informative_features(30)
# Out:
# Most Informative Features
#              last_letter = 'a'            female : male   =     33.1 : 1.0
#              last_letter = 'k'              male : female =     31.5 : 1.0
#              last_letter = 'p'              male : female =     19.9 : 1.0
#              last_letter = 'f'              male : female =     16.8 : 1.0
#              last_letter = 'v'              male : female =     10.6 : 1.0
#              last_letter = 'd'              male : female =     10.1 : 1.0
#              last_letter = 'm'              male : female =      9.1 : 1.0
#              last_letter = 'o'              male : female =      9.0 : 1.0
#              penultimate = 'o'              male : female =      8.0 : 1.0
#              penultimate = 'u'              male : female =      7.0 : 1.0
#              last_letter = 'r'              male : female =      6.7 : 1.0
#              last_letter = 'w'              male : female =      6.6 : 1.0
#              last_letter = 'g'              male : female =      5.1 : 1.0
#              last_letter = 'z'              male : female =      5.1 : 1.0
#              last_letter = 's'              male : female =      4.6 : 1.0
#              last_letter = 't'              male : female =      4.3 : 1.0
#              last_letter = 'b'              male : female =      4.1 : 1.0
#              last_letter = 'j'              male : female =      4.0 : 1.0
#              penultimate = 'E'              male : female =      4.0 : 1.0
#              penultimate = 'y'            female : male   =      3.5 : 1.0
#              last_letter = 'i'            female : male   =      3.5 : 1.0
#              penultimate = 'x'            female : male   =      3.3 : 1.0
#              last_letter = 'u'              male : female =      3.3 : 1.0
#              penultimate = 'f'              male : female =      3.1 : 1.0
#              penultimate = 'n'            female : male   =      2.9 : 1.0
#              penultimate = 't'            female : male   =      2.6 : 1.0
#              penultimate = 'a'              male : female =      2.6 : 1.0
#              penultimate = 'j'            female : male   =      2.5 : 1.0
#              penultimate = 's'            female : male   =      2.3 : 1.0
#              last_letter = 'n'              male : female =      2.1 : 1.0

# %%
print(train_set)
# Out:
# [({'last_letter': 'n', 'penultimate': 'a'}, 'female'), ({'last_letter': 'e', 'penultimate': 'i'}, 'female'), ...]
